# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#比赛描述" data-toc-modified-id="比赛描述-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>比赛描述</a></span></li><li><span><a href="#数据及具体目标" data-toc-modified-id="数据及具体目标-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>数据及具体目标</a></span></li><li><span><a href="#实施流程" data-toc-modified-id="实施流程-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>实施流程</a></span></li><li><span><a href="#代码实现" data-toc-modified-id="代码实现-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>代码实现</a></span><ul class="toc-item"><li><span><a href="#导入相关包" data-toc-modified-id="导入相关包-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>导入相关包</a></span></li><li><span><a href="#读取数据" data-toc-modified-id="读取数据-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>读取数据</a></span></li><li><span><a href="#数据预处理" data-toc-modified-id="数据预处理-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>数据预处理</a></span><ul class="toc-item"><li><span><a href="#日期数据处理" data-toc-modified-id="日期数据处理-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>日期数据处理</a></span></li><li><span><a href="#合并数据集" data-toc-modified-id="合并数据集-4.3.2"><span class="toc-item-num">4.3.2&nbsp;&nbsp;</span>合并数据集</a></span></li><li><span><a href="#构造新特征" data-toc-modified-id="构造新特征-4.3.3"><span class="toc-item-num">4.3.3&nbsp;&nbsp;</span>构造新特征</a></span></li><li><span><a href="#运用五折交叉验证和贝叶斯平滑技术来构造新特征" data-toc-modified-id="运用五折交叉验证和贝叶斯平滑技术来构造新特征-4.3.4"><span class="toc-item-num">4.3.4&nbsp;&nbsp;</span>运用五折交叉验证和<a href="https://blog.csdn.net/qq_35661896/article/details/102622076" rel="nofollow" target="_blank">贝叶斯平滑技术</a>来构造新特征</a></span></li><li><span><a href="#划分数据集" data-toc-modified-id="划分数据集-4.3.5"><span class="toc-item-num">4.3.5&nbsp;&nbsp;</span>划分数据集</a></span></li></ul></li><li><span><a href="#模型建立与求解" data-toc-modified-id="模型建立与求解-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>模型建立与求解</a></span><ul class="toc-item"><li><span><a href="#模型一-XGBoost" data-toc-modified-id="模型一-XGBoost-4.4.1"><span class="toc-item-num">4.4.1&nbsp;&nbsp;</span>模型一 <a href="https://www.cnblogs.com/simpleye1/p/13946653.html" rel="nofollow" target="_blank">XGBoost</a></a></span><ul class="toc-item"><li><span><a href="#参数设置" data-toc-modified-id="参数设置-4.4.1.1"><span class="toc-item-num">4.4.1.1&nbsp;&nbsp;</span><a href="https://blog.csdn.net/wuxiaosi808/article/details/78036633" rel="nofollow" target="_blank">参数设置</a></a></span></li><li><span><a href="#XGBoost-模型训练和预测" data-toc-modified-id="XGBoost-模型训练和预测-4.4.1.2"><span class="toc-item-num">4.4.1.2&nbsp;&nbsp;</span>XGBoost 模型训练和预测</a></span></li><li><span><a href="#模型结果保存" data-toc-modified-id="模型结果保存-4.4.1.3"><span class="toc-item-num">4.4.1.3&nbsp;&nbsp;</span>模型结果保存</a></span></li></ul></li><li><span><a href="#模型二-LightGBM" data-toc-modified-id="模型二-LightGBM-4.4.2"><span class="toc-item-num">4.4.2&nbsp;&nbsp;</span>模型二 <a href="https://www.cnblogs.com/simpleye1/p/13946653.html" rel="nofollow" target="_blank">LightGBM</a></a></span><ul class="toc-item"><li><span><a href="#参数设置" data-toc-modified-id="参数设置-4.4.2.1"><span class="toc-item-num">4.4.2.1&nbsp;&nbsp;</span>参数设置</a></span></li><li><span><a href="#LightGBM-模型训练和预测" data-toc-modified-id="LightGBM-模型训练和预测-4.4.2.2"><span class="toc-item-num">4.4.2.2&nbsp;&nbsp;</span>LightGBM 模型训练和预测</a></span></li><li><span><a href="#模型结果保存" data-toc-modified-id="模型结果保存-4.4.2.3"><span class="toc-item-num">4.4.2.3&nbsp;&nbsp;</span>模型结果保存</a></span></li></ul></li></ul></li></ul></li></ul></div>

# %% [markdown]
# <h1><font size=6>TalkingData广告反欺诈检测挑战</font><span class="tocSkip"></span></h1>
#
# &emsp;&emsp;**<font size=3>[2018-Kaggle-AdTrackingFraud][1]</font>**
#
# [1]: https://github.com/ShawnyXiao/2018-Kaggle-AdTrackingFraud

# %% [markdown]
# # 比赛描述

# %% [markdown]
# &emsp;&emsp;欺诈风险无处不在，但对于在线做广告的公司来说，**点击欺诈可能会以压倒性的数量发生**，从而导致误导性点击数据和浪费金钱。广告渠道可以通过简单地大规模点击广告来推高成本。中国每月活跃使用的智能移动设备超过 10 亿台，是最大的全球移动市场，因此遭受大量欺诈流量的困扰。\
# &emsp;&emsp;TalkingData 是中国最大的独立大数据服务平台，覆盖全国 70% 以上的活跃移动设备。**他们每天处理 30 亿次点击，其中 90% 可能是欺诈性的**。他们目前为应用程序开发人员防止点击欺诈的方法是衡量用户在其投资组合中的点击历程，并标记产生大量点击但从未最终安装应用程序的 IP 地址。有了这些信息，**他们建立了 IP 黑名单和设备黑名单。**\
# &emsp;&emsp;虽然成功，但他们希望始终比欺诈者领先一步，因此转向 Kaggle 社区寻求帮助以进一步开发他们的解决方案，那么在本次比赛中呢，**我们要面临的挑战是构建一种算法来预测用户在点击移动应用广告后是否会下载应用 app。**为了支持您的建模，TalkingData 提供了一个庞大的数据集，涵盖 4 天内大约 2 亿次点击！

# %% [markdown]
# # 数据及具体目标

# %% [markdown]
# <font size=3> &emsp;&emsp;**★ 文件描述** \
# &emsp;&emsp;&emsp;train.csv - 7G多的训练集 \
# &emsp;&emsp;&emsp;train_sample.csv - 100,000 行随机选择的训练数据，用于在下载完整集之前检查数据 \
# &emsp;&emsp;&emsp;test.csv - 800多M的测试集 \
# &emsp;&emsp;&emsp;sample_submission.csv - 格式正确的示例提交文件 \
# &emsp;&emsp;&emsp;UPDATE: test_supplement.csv - 一个更大的测试集，无意中发布。没有必要使用这些数据，官方测试数据是该数据的一个子集。 \
# &emsp;&emsp;**★ 数据字段** \
# &emsp;&emsp;&emsp;TalkingData 提供了样本量近1.9亿的训练数据，包括了2017.11.06至2017.11.09四天时间内的数据，训练集的每一行为一次广告点击\
# &emsp;&emsp;记录，包括以下字段： \
# &emsp;&emsp;&emsp;&emsp;&emsp;**ip**：点击的ip地址 \
# &emsp;&emsp;&emsp;&emsp;&emsp;**app**：用于营销的应用程序 id \
# &emsp;&emsp;&emsp;&emsp;&emsp;**device**：用户的移动设备类型 id（如iphone 6 plus、iphone 7、huawei mate 7等） \
# &emsp;&emsp;&emsp;&emsp;&emsp;**os**：用户移动设备的操作系统版本 id \
# &emsp;&emsp;&emsp;&emsp;&emsp;**channel**：广告投放渠道 id \
# &emsp;&emsp;&emsp;&emsp;&emsp;**click_time**：点击时间戳（UTC时间），yyyy-mm-dd hh:mm:ss \
# &emsp;&emsp;&emsp;&emsp;&emsp;**attributed_time**：如果用户点击广告后下载了应用程序，这就是应用程序下载时间 \
# &emsp;&emsp;&emsp;&emsp;&emsp;**is_attributed**：要预测的目标，表示是否下载了app \
# &emsp;&emsp;&emsp;请注意，ip、app、device、os 和 channel 都是分类变量且经过编码处理。测试集类似，有以下区别： \
# &emsp;&emsp;&emsp;&emsp;&emsp;**click_id**：进行预测的参考 \
# &emsp;&emsp;&emsp;&emsp;&emsp;**is_attributed**：不包括在内 \
# </font>

# %% [markdown]
# <font size=3>                 \
# &emsp;&emsp;**★ 最终目标：预测用户在点击移动应用广告后是否会下载 app。具体来说呢，就是对于测试集中的每个 click_id，预测目标变量 \
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;is_attributed 的概率即用户下载 app 的概率。**    \
# &emsp;&emsp;**★ 评估指标：要求用 AUC 作为评判标准，即预测概率和观察目标之间的 ROC 曲线下的面积。**
# </font>

# %% [markdown]
# # 实施流程

# %% [markdown]
# <font size=3>&emsp;&emsp;（1）了解分析问题，导入相关包，读取数据； \
# &emsp;&emsp;（2）进行数据预处理和特征工程工作，主要包括日期数据处理、构造新特征、五折交叉验证、划分数据集等等； \
# &emsp;&emsp;（3）分别建立 XGBoost 和 LightGBM 模型，并进行模型的训练和预测； \
# &emsp;&emsp;（4）保存最优模型并提交结果。</font>

# %% [markdown]
# # 代码实现

# %% [markdown]
# ## 导入相关包

# %%
import numpy as np
import pandas as pd
import dask.dataframe as dd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('darkgrid')
from sklearn import preprocessing
from sklearn.model_selection import KFold
import xgboost as xgb
import lightgbm as lgb
import _pickle as cPickle
import time
import datetime
import math
import gc
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 读取数据

# %%
# 声明根目录和初始化特征列表
root_path = './data/'
predictors = []

# %%
# 定义辅助函数log()
def log(info):
    print(time.strftime("%Y-%m-%d %H:%M:%S", time.localtime()) + ' ' + str(info))
    
# 定义辅助函数log_shape()
def log_shape(train, test):
    log('Train data shape: %s' % str(train.shape))
    log('Test data shape: %s' % str(test.shape))
    
# 读取数据集
log('Read data...')
dtypes = {
    'click_id': 'uint32',
    'ip': 'uint32',
    'app': 'uint16',
    'device': 'uint16',
    'os': 'uint16',
    'channel': 'uint16',
    'is_attributed': 'uint8'
}

train_dd = dd.read_csv(root_path + './input/train.csv', dtype=dtypes)
log('Original Train data rows: %s' % str(len(train_dd))) # 计算原始数据集的行数
print(train_dd.columns)
del train_dd
gc.collect()

# skiprows=np.random.choice(np.arange(1, lines), size=lines-1-18000000, replace=False)
train = pd.read_csv(root_path + 'input/train.csv', skiprows=lambda i: i > 0 and np.random.random() > 0.1, nrows=18000000, 
                    header=0, sep=',', dtype=dtypes, usecols=['ip', 'app', 'device', 'os', 'channel', 'click_time', 'is_attributed'])
test = pd.read_csv(root_path + 'input/test.csv', header=0, sep=',', dtype=dtypes,
                   usecols=['ip', 'app', 'device', 'os', 'channel', 'click_time'])
log('Read data done!')
log_shape(train, test)
# Out:
# 2023-04-12 02:56:18 Read data...
# 2023-04-12 02:57:02 Original Train data rows: 184903890
# Index(['ip', 'app', 'device', 'os', 'channel', 'click_time', 'attributed_time',
#        'is_attributed'],
#       dtype='object')
# 2023-04-12 02:59:05 Read data done!
# 2023-04-12 02:59:05 Train data shape: (18000000, 7)
# 2023-04-12 02:59:05 Test data shape: (18790469, 6)

# %%
# 取出训练集目标变量is_attributed，统计标签0和1的频数并绘图
Y_train = train["is_attributed"]
g = sns.countplot(Y_train)
print(Y_train.value_counts())
print(Y_train.value_counts()/Y_train.value_counts().sum())
del Y_train
gc.collect();
# Out:
# 0    17955004
# 1       44996
# Name: is_attributed, dtype: int64
# 0    0.9975
# 1    0.0025
# Name: is_attributed, dtype: float64

# %% [markdown]
# ## 数据预处理
# ### 日期数据处理

# %%
# 定义日期数据处理函数process_date()
def process_date(df):
    format = '%Y-%m-%d %H:%M:%S'
    df['date'] = pd.to_datetime(df['click_time'], format=format)
    df['month'] = df['date'].dt.month.astype('uint8')
    df['weekday'] = df['date'].dt.weekday.astype('uint8')
    df['day'] = df['date'].dt.day.astype('uint8')
    df['hour'] = df['date'].dt.hour.astype('uint8')
    df['minute'] = df['date'].dt.minute.astype('uint8')
    df['second'] = df['date'].dt.second.astype('uint8')
    df['tm_hour'] = (df['hour'] + df['minute'] / 60.0).astype('float32')
    df['tm_hour_sin'] = (df['tm_hour'].map(lambda x: math.sin((x - 12) / 12 * 2 * math.pi))).astype('float32')
    df['tm_hour_cos'] = (df['tm_hour'].map(lambda x: math.cos((x - 12) / 12 * 2 * math.pi))).astype('float32')
    del df['click_time']
    return df

log('Process date...')
train = process_date(train)
test = process_date(test)
gc.collect()
log('Process date done!')
log_shape(train, test)
# Out:
# 2023-04-12 02:59:05 Process date...
# 2023-04-12 02:59:52 Process date done!
# 2023-04-12 02:59:52 Train data shape: (18000000, 16)
# 2023-04-12 02:59:52 Test data shape: (18790469, 15)

# %%
# 定义绘图函数plot_time()
def plot_time(df, time):
    plt.figure(figsize=(14, 4))
    plt.rcParams["font.sans-serif"]=["SimHei"]
    plt.rcParams["axes.unicode_minus"]=False
    plt.subplot(121)
    plt.plot(df[[time, 'is_attributed']].groupby([time], as_index=True).sum())
    plt.xlabel(time)
    plt.ylabel('下载app次数');
    
    plt.subplot(122)
    plt.plot(df[[time, 'is_attributed']].groupby([time], as_index=True).mean())
    plt.xlabel(time)
    plt.ylabel('平均下载app次数');

# 检查每小时模式，每分钟模式等等
plot_time(train, 'hour')
plot_time(train, 'tm_hour')
plot_time(train, 'minute')
plot_time(train, 'second')
plot_time(train, 'tm_hour_sin')
plot_time(train, 'tm_hour_cos')
gc.collect();
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# ...

# %% [markdown]
# ### 合并数据集

# %%
log('Train append test...')
df = train.append(test).reset_index(drop=True)
del train
del test
gc.collect()
log('Train append test done!')
# Out:
# 2023-04-12 02:59:58 Train append test...
# 2023-04-12 03:00:03 Train append test done!

# %%
# 查看特征工程前的数据集
log('Before feature engineer')
log('Num of samples: ' + str(len(df.index)))
log('Num of features: ' + str(len(df.columns)))
log('Features: ' + str(df.columns))
# Out:
# 2023-04-12 03:00:03 Before feature engineer
# 2023-04-12 03:00:03 Num of samples: 36790469
# 2023-04-12 03:00:03 Num of features: 16
# 2023-04-12 03:00:03 Features: Index(['ip', 'app', 'device', 'os', 'channel', 'is_attributed', 'date',
#        'month', 'weekday', 'day', 'hour', 'minute', 'second', 'tm_hour',
#        'tm_hour_sin', 'tm_hour_cos'],
#       dtype='object')

# %% [markdown]
# ### 构造新特征

# %%
# 定义特征函数cal_next_time_delta()
def cal_next_time_delta(df, suffix, type='float32'):
    groupby_columns = [
        {'columns': ['ip', 'app', 'channel', 'device', 'os']},
        {'columns': ['ip', 'os', 'device']},
        {'columns': ['ip', 'os', 'device', 'app']}
    ]
    # 计算下一次点击与本次点击相隔的时间差
    for spec in groupby_columns:
        # 新特征名
        new_name = '{}_{}'.format('_'.join(spec['columns']), suffix)
        # 可供选择的所有特征列表
        all_features = spec['columns'] + ['date']
        # 计算新特征值
        log('Calculate ' + suffix + '...')
        df[new_name] = (df[all_features].groupby(spec['columns']).date.shift(-1) - df.date).dt.seconds.astype(type)
        predictors.append(new_name)
        gc.collect()
    return df

log('Cal next_time_delta')
df = cal_next_time_delta(df, 'next_time_delta', 'float32')
gc.collect();
# Out:
# 2023-04-12 03:00:03 Cal next_time_delta
# 2023-04-12 03:00:03 Calculate next_time_delta...
# 2023-04-12 03:00:23 Calculate next_time_delta...
# 2023-04-12 03:00:30 Calculate next_time_delta...

# %%
# 观察新特征与目标变量相关性
train_len = 18000000
plot_time(df[: train_len], 'ip_app_channel_device_os_next_time_delta')
plot_time(df[: train_len], 'ip_os_device_next_time_delta')
plot_time(df[: train_len], 'ip_os_device_app_next_time_delta')
gc.collect();
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# ...

# %%
# 构造特征函数cal_prev_time_delta()
def cal_prev_time_delta(df, suffix, type='float32'):
    groupby_columns = [
        {'columns': ['ip', 'channel']},
        {'columns': ['ip', 'os']}
    ]
    # 计算本次点击与上一次点击相隔的时间差
    for spec in groupby_columns:
        # 新特征名
        new_name = '{}_{}'.format('_'.join(spec['columns']), suffix)
        # 可供选择的所有特征列表
        all_features = spec['columns'] + ['date']
        # 计算新特征值
        log('Calculate ' + suffix + '...')
        df[new_name] = (df.date - df[all_features].groupby(spec['columns']).date.shift(+1)).dt.seconds.astype(type)
        predictors.append(new_name)
        gc.collect()
    return df

log('Cal prev_time_delta')
df = cal_prev_time_delta(df, 'prev_time_delta', 'float32')
gc.collect();
# Out:
# 2023-04-12 03:00:52 Cal prev_time_delta
# 2023-04-12 03:00:52 Calculate prev_time_delta...
# 2023-04-12 03:01:04 Calculate prev_time_delta...

# %%
# 观察新特征与目标变量相关性
plot_time(df[: train_len], 'ip_channel_prev_time_delta')
plot_time(df[: train_len], 'ip_os_prev_time_delta')
gc.collect();
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# ...

# %%
# 构造特征函数merge_nunique()
def merge_nunique(df, columns_groupby, column, new_column_name, type='uint64'):
    add = pd.DataFrame(df.groupby(columns_groupby)[column].nunique()).reset_index()
    add.columns = columns_groupby + [new_column_name]
    df = df.merge(add, on=columns_groupby, how="left")
    df[new_column_name] = df[new_column_name].astype(type)
    predictors.append(new_column_name)
    return df

log('Cal nunique_channel_gb_ip')
df = merge_nunique(df, ['ip'], 'channel', 'nunique_channel_gb_ip', 'uint32')
gc.collect()

log('Cal nunique_app_gb_ip_device_os')
df = merge_nunique(df, ['ip', 'device', 'os'], 'app', 'nunique_app_gb_ip_device_os', 'uint32')
gc.collect()

log('Cal nunique_hour_gb_ip_day')
df = merge_nunique(df, ['ip', 'day'], 'hour', 'nunique_hour_gb_ip_day', 'uint32')
gc.collect()

log('Cal nunique_app_gb_ip')
df = merge_nunique(df, ['ip'], 'app', 'nunique_app_gb_ip', 'uint32')
gc.collect()

log('Cal nunique_os_gb_ip_app')
df = merge_nunique(df, ['ip', 'app'], 'os', 'nunique_os_gb_ip_app', 'uint32')
gc.collect()

log('Cal nunique_device_gb_ip')
df = merge_nunique(df, ['ip'], 'device', 'nunique_device_gb_ip', 'uint32')
gc.collect()

log('Cal nunique_channel_gb_app')
df = merge_nunique(df, ['app'], 'channel', 'nunique_channel_gb_app', 'uint32')
gc.collect();
# Out:
# 2023-04-12 03:01:18 Cal nunique_channel_gb_ip

# %%
# 观察新特征与目标变量相关性
# plot_time(df[: train_len], 'nunique_channel_gb_ip')
# plot_time(df[: train_len], 'nunique_app_gb_ip_device_os')
plot_time(df[: train_len], 'nunique_hour_gb_ip_day')
# plot_time(df[: train_len], 'nunique_app_gb_ip')
# plot_time(df[: train_len], 'nunique_app_gb_ip_device_os')
# plot_time(df[: train_len], 'nunique_app_gb_ip_device_os')
# plot_time(df[: train_len], 'nunique_app_gb_ip_device_os')
gc.collect();

# %%
# 构造特征函数merge_cumcount()
def merge_cumcount(df, columns_groupby, column, new_column_name, type='uint64'):
    df[new_column_name] = df.groupby(columns_groupby)[column].cumcount().values.astype(type)
    predictors.append(new_column_name)
    return df

log('Cal cumcount_os_gb_ip')
df = merge_cumcount(df, ['ip'], 'os', 'cumcount_os_gb_ip', 'uint32')
gc.collect();

log('Cal cumcount_app_gb_ip_device_os')
df = merge_cumcount(df, ['ip', 'device', 'os'], 'app', 'cumcount_app_gb_ip_device_os', 'uint32')
gc.collect();

# %%
# cumcount函数举例
X = pd.DataFrame([['a'], ['null'], ['a'], ['b'], ['b'], ['a']], columns=['A'])
X

# %%
X.groupby('A').cumcount()

# %%
del X
gc.collect();

# %%
# 构造特征函数merge_count()
def merge_count(df, columns_groupby, new_column_name, type='uint64'):
    add = pd.DataFrame(df.groupby(columns_groupby).size()).reset_index()
    add.columns = columns_groupby + [new_column_name]
    df = df.merge(add, on=columns_groupby, how="left")
    df[new_column_name] = df[new_column_name].astype(type)
    predictors.append(new_column_name)
    return df

log('Cal count_gb_ip_day_hour')
df = merge_count(df, ['ip', 'day', 'hour'], 'count_gb_ip_day_hour', 'uint32')
gc.collect()

log('Cal count_gb_ip_app')
df = merge_count(df, ['ip', 'app'], 'count_gb_ip_app', 'uint32')
gc.collect()

log('Cal count_gb_ip_app_os')
df = merge_count(df, ['ip', 'app', 'os'], 'count_gb_ip_app_os', 'uint32')
gc.collect();

# %%
# 构造特征函数merge_var()
def merge_var(df, columns_groupby, column, new_column_name, type='float64'):
    add = pd.DataFrame(df.groupby(columns_groupby)[column].var()).reset_index()
    add.columns = columns_groupby + [new_column_name]
    df = df.merge(add, on=columns_groupby, how="left")
    df[new_column_name] = df[new_column_name].astype(type)
    predictors.append(new_column_name)
    return df

log('Cal var_day_gb_ip_app_os')
df = merge_var(df, ['ip', 'app', 'os'], 'day', 'var_day_gb_ip_app_os', 'float32')
gc.collect();

# %%
# 检查特征工程后的数据集
log('After feature engineer')
log('Num of samples: ' + str(len(df.index)))
log('Num of features: ' + str(len(df.columns)))
log('Features: ' + str(df.columns))

# %%
# 保存所有的特征
cPickle.dump(df, open(root_path + 'output/feat/all.p', 'wb'))
# 重新加载所有特征
# df = cPickle.load(open(root_path + 'output/feat/all.p', 'rb'))

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 分离训练集和测试集
log('Train test divid...')
train = df[:train_len]
test = df[train_len:]
del df
gc.collect()
log_shape(train, test)
log('Train test divid done!')

# %% [markdown]
# ### 运用五折交叉验证和[贝叶斯平滑技术][1]来构造新特征
#
# [1]:https://blog.csdn.net/qq_35661896/article/details/102622076

# %% [markdown]
# CTR（Ad Click-through Rate）：广告点击率 \
# CVR（Ad Conversion Rate）：广告转化率，是指通过点击广告进入推广网站的网民形成转化的比例，在本题中也可以理解为用户下载 app 的概率
#
# [CVR预估][1][之贝叶斯平滑][2] \
# 在实际工作中，在大量数据下广告转化率这个指标是有效的，比如某个广告点击量是10000次，转化量是100次，那转化率就是1%。但是，我们本题要去预测每一次点击记录下的广告转化率即用户下载 app 的概率，从大样本角度来说，要么下载要么不下载，概率都是0.5，然而这肯定不是我们想要的结果。 \
# 如果我们能够利用已有的历史数据和所有的先验知识，对CVR进行平滑，以此来模拟实际的CVR，那就再好不过了。这就用到了著名的贝叶斯平滑技术。
#
# [1]:http://www.manongjc.com/detail/12-ppdjnloxrjcvolq.html
# [2]:https://blog.csdn.net/jinping_shi/article/details/78334362

# %% [markdown]
# 贝叶斯平滑的思想是给CVR预设一个经验初始值，再通过当前的转化量和点击量来修正这个初始值。\
# 针对本题，对于每一条点击记录X，要么下载app要么不下载app，其服从0-1分布也就是伯努利分布：$ X \sim Ber(r) $ ,其中r是该点击记录用户下载app的概率。我们要做的就是通过贝叶斯平滑技术来计算转化率 $r$ 的估计值  $\hat r$.
#
# 在贝叶斯框架下，我们假设转化率 $r$ 服从某个分布：$r \sim \pi(r)$ \
# 因为这是基于经验或者说先验知识的，所以这个分布称为先验分布。既然有先验分布，就有后验分布。记 $r$ 的后验分布为 $\pi(r|x)$ ，其中x就是样本信息，包含了转化量和点击量等信息。贝叶斯估计的实质就是求后验分布，即基于当前的转化量 $V$ 和点击量 $C$ ，求转化率的分布 $r$ 。
#
# 根据贝叶斯公式就可以计算出$r$ 的后验分布 $\pi(r|x)$：$$ \pi(r|x)=\frac {f(x|r)\pi(r)}{f(x)}\ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ (1)$$
#
#  $r$ 的后验分布为 $\pi(r|x)$ 是一个概率密度函数，无法知道 $r$ 确切的值。那么如何求出 $r$ 的估计值呢？这里需要通过损失函数来约束，也就是说求 $\hat r$ 必须使得损失函数 $ L(\hat r, r)=(\hat r-r)^2 $ 在 $r$ 的后验分布上的期望最小。这句话翻译成数学公式就是：
# $$ arg\,min \int L(\hat r, r) \pi(r|x) dr\ \ \ \ \ \ \ (2)$$
#
# 通过上述两个公式就能求出 $r$ 的估计值了，但是实际计算时通常不用去计算积分，因为满足一定条件，$\pi(r)$ 跟 $\pi(r|x)$ 有一样的形式，这里就必须提及一下共轭先验的概念。
#
# **共轭先验：**如果后验概率分布 $\pi(r|x)$ 和先验概率分布 $\pi(r)$ 有相同的形式，则 $\pi(r|x)$ 和 $\pi(r)$ 统称共轭分布。
#
# 也就是说，如果我能找到一个 $\pi(r)$ ,它是 $f(x|r)$ 的共轭先验，那么 $r$ 的后验分布 $\pi(r|x)$ 和先验分布 $\pi(r)$ 会有一样的形式。
#
# 之前，假设用户是否下载 app 服从伯努利分布，参数为 $r$，下载 app 次数（转化量 $V$）服从二项分布：$ f(C,I|r) \sim Bin(r) $
#
# **二项分布的共轭先验是 Beta 分布，即 $ \pi(r) \sim Beta(\alpha, \beta) $**
#
# 根据共轭先验的定义，$\pi(r|x)$ 和 $\pi(r)$ 有相同的形式，即 $ \pi(r|x) \sim Beta(\alpha', \beta') $，由此求出 $\pi(r|x)$带入公式（2）就能求出 $\hat r$ ：$$ \hat r=\frac {V+\alpha}{C+\alpha+\beta} $$
#
# 其中， $V$ 和 $C$ 就是转化量和点击量，$\alpha$ 和 $\beta$ 可以通过矩估计方法求得，用样本的均值代替总体的期望，用样本的方差代替总体的方差，这里直接给出公式：
# $$ \alpha=\overline X \left(\frac {\overline X(1-\overline X)}{S^2} - 1\right) $$
# $$ \beta=(1-\overline X) \left(\frac {\overline X(1-\overline X)}{S^2} - 1\right) $$

# %%
# 构造特征函数merge_sum()
def merge_sum(df, columns_groupby, column, new_column_name, type='float64'):
    add = pd.DataFrame(df.groupby(columns_groupby)[column].sum()).reset_index()
    add.columns = columns_groupby + [new_column_name]
    df = df.merge(add, on=columns_groupby, how="left")
    df[new_column_name] = df[new_column_name].astype(type)
    # predictors.append(new_column_name)  
    return df

# 定义BayesianSmoth类（贝叶斯平滑）
class BayesianSmoth(object):
    def __init__(self, alpha=0, beta=0):
        self.alpha = alpha
        self.beta = beta

    def update_moment(self, tries, success):
        '''使用矩估计来估计alpha,beta'''
        mean, var = self.__compute_moment(tries, success)
        self.alpha = (mean + 0.000001) * ((mean + 0.000001) * (1.000001 - mean) / (var + 0.000001) - 1)
        self.beta = (1.000001 - mean) * ((mean + 0.000001) * (1.000001 - mean) / (var + 0.000001) - 1)
        print(self.alpha, self.beta)
        return (self.alpha + success) / (self.alpha + self.beta + tries)  # 返回参数的矩估计结果

    def __compute_moment(self, tries, success):   #这里tries指的是样本数，success指的是成功数，即下载app的次数
        # 计算均值和方差
        '''矩估计'''
        ctr_list = []
        mean = (success / tries).mean()
        if len(tries) == 1:
            var = 0
        else:
            var = (success / tries).var()
        return mean, var

# 定义特征函数cal_cvr()，运用五折交叉验证的方式去计算cvr特征
def cal_cvr(train, test, type='float32'):
    train['cvr_gb_ip_day_hour'] = 0
    train['cvr_gb_ip_app'] = 0
    train['cvr_gb_ip_app_os'] = 0

    # 按列表定义分组
    idh = ['ip', 'day', 'hour']
    ia = ['ip', 'app']
    iao = ['ip', 'app', 'os']

    kf = KFold(n_splits=5, shuffle=True, random_state=7)

    for i, (train_index, test_index) in enumerate(kf.split(train)):
        log('Fold ' + str(i) + ' begin...')

        # 按folds划分训练集和测试集
        tr = train.iloc[train_index, :train.shape[1] - 3]
        te = train.iloc[test_index, :train.shape[1] - 3]

        # 计算folds内训练集的总和
        log('Cal sum_label_gb_ip_day_hour')
        tr = merge_sum(tr, idh, 'is_attributed', 'sum_label_gb_ip_day_hour')
        log('Cal sum_label_gb_ip_app')
        tr = merge_sum(tr, ia, 'is_attributed', 'sum_label_gb_ip_app')
        log('Cal sum_label_gb_ip_app_os')
        tr = merge_sum(tr, iao, 'is_attributed', 'sum_label_gb_ip_app_os')

        # 使用贝叶斯平滑技术计算folds内训练集的 cvr
        tr['cvr_gb_ip_day_hour'] = BayesianSmoth().update_moment(tr['count_gb_ip_day_hour'], tr['sum_label_gb_ip_day_hour'])
        tr['cvr_gb_ip_app'] = BayesianSmoth().update_moment(tr['count_gb_ip_app'], tr['sum_label_gb_ip_app'])
        tr['cvr_gb_ip_app_os'] = BayesianSmoth().update_moment(tr['count_gb_ip_app_os'], tr['sum_label_gb_ip_app_os'])

        # 将folds内的测试集与训练集 cvr 特征合并
        te = te.merge(tr[['cvr_gb_ip_day_hour'] + idh].drop_duplicates(subset=idh, keep='first'), on=idh, how='left')
        te = te.merge(tr[['cvr_gb_ip_app'] + ia].drop_duplicates(subset=ia, keep='first'), on=ia, how='left')
        te = te.merge(tr[['cvr_gb_ip_app_os'] + iao].drop_duplicates(subset=iao, keep='first'), on=iao, how='left')

        # 并将其放入原始的训练集中
        train['cvr_gb_ip_day_hour'] += te['cvr_gb_ip_day_hour']
        train['cvr_gb_ip_app'] += te['cvr_gb_ip_app']
        train['cvr_gb_ip_app_os'] += te['cvr_gb_ip_app_os']

        del tr, te
        log('Fold ' + str(i) + ' Done!')

    # 转换数据类型
    train['cvr_gb_ip_day_hour'] = train['cvr_gb_ip_day_hour'].astype(type)
    train['cvr_gb_ip_app'] = train['cvr_gb_ip_app'].astype(type)
    train['cvr_gb_ip_app_os'] = train['cvr_gb_ip_app_os'].astype(type)

    # 合并原始训练集到测试集中
    test = test.merge(train[['cvr_gb_ip_day_hour'] + idh].drop_duplicates(subset=idh, keep='first'), on=idh, how='left')
    test = test.merge(train[['cvr_gb_ip_app'] + ia].drop_duplicates(subset=ia, keep='first'), on=ia, how='left')
    test = test.merge(train[['cvr_gb_ip_app_os'] + iao].drop_duplicates(subset=iao, keep='first'), on=iao, how='left')

    predictors.append('cvr_gb_ip_day_hour')
    predictors.append('cvr_gb_ip_app')
    predictors.append('cvr_gb_ip_app_os')

    return train, test

# 计算cvr特征（广告转化率）
log('Cal cvr...')
train, test = cal_cvr(train, test, 'float32')
log('Cal cvr done!')
log_shape(train, test)

# %%
# 保存cvr特征
cvr_feats = ['cvr_gb_ip_day_hour', 'cvr_gb_ip_app', 'cvr_gb_ip_app_os']
cPickle.dump(train[cvr_feats], open(root_path + 'output/feat/train_cvr.p', 'wb'))
cPickle.dump(test[cvr_feats], open(root_path + 'output/feat/test_cvr.p', 'wb'))

# %%
# 重新加载cvr特征
# train_cvr = cPickle.load(open(root_path + 'output/feat/train_cvr.p', 'rb'))
# test_cvr = cPickle.load(open(root_path + 'output/feat/test_cvr.p', 'rb'))
# train = pd.concat([train, train_cvr], axis=1)
# test = pd.concat([test, test_cvr], axis=1)
# del train_cvr, test_cvrx

# %% [markdown]
# ### 划分数据集

# %%
# 定义数据集划分函数spilt_local_train_test()
def spilt_local_train_test(df, train_size, test_size):
    local_train = df[:train_size]
    local_test = df[train_size:train_size + test_size]
    return local_train, local_test

# %%
log('Split dataset to get local train/test set...')
local_train_size = 14400000
local_test_size = 3600000
local_train, local_test = spilt_local_train_test(train, local_train_size, local_test_size)
log('Split dataset to get local train/test set done!')

log('================================= Local data info ======================================')
log('Local train shape:' + str(local_train.shape))
log('Local test shape:' + str(local_test.shape))
log('Local train label ratio (0-1):' + str(local_train.is_attributed.value_counts().values * 1.0 / local_train.shape[0]))
log('Local train label number (0-1):' + str(local_train.is_attributed.value_counts().values))
log('Local train min/max date:' + str(local_train.date.min()) + ',' + str(local_train.date.max()))
log('Local test min/max date:' + str(local_test.date.min()) + ',' + str(local_test.date.max()))
log('========================================================================================')

log('================================= Online data info =====================================')
log('Online train shape:' + str(train.shape))
log('Online test shape:' + str(test.shape))
log('Online train label ratio (0-1):' + str(train.is_attributed.value_counts().values * 1.0 / train.shape[0]))
log('Online train label number (0-1):' + str(train.is_attributed.value_counts().values))
log('Online train min/max date:' + str(train.date.min()) + ',' + str(train.date.max()))
log('Online train min/max date:' + str(test.date.min()) + ',' + str(test.date.max()))
log('========================================================================================')

# %%
# 定义模型输入数据函数get_model_input_data()
def get_model_input_data(train, test, is_local):
    feat = ['ip', 'app', 'device', 'os', 'channel', 'hour']
    for f in feat:
        if f not in predictors:
            predictors.append(f)
    train_x = train[predictors]
    train_y = train.is_attributed.values
    if is_local == 1:
        test_x = test[train_x.columns.values]
        test_y = test.is_attributed.values
        return train_x, train_y, test_x, test_y
    else:
        test_x = test[train_x.columns.values]
        return train_x, train_y, test_x

# %%
log('Get local model input data...')
local_train_x, local_train_y, local_test_x, local_test_y = get_model_input_data(local_train, local_test, is_local=1)
del local_train
del local_test
gc.collect()
log_shape(local_train_x, local_test_x)
log('Get local model input data done!')

# %%
log('Get online model input data...')
online_train_x, online_train_y, online_test_x = get_model_input_data(train, test, is_local=0)
del train
del test
gc.collect()
log_shape(online_train_x, online_test_x)
log('Get online model input data done!')

# %%
predictors

# %% [markdown]
# ## 模型建立与求解
# ### 模型一 [XGBoost][1]
#
# [1]:https://www.cnblogs.com/simpleye1/p/13946653.html

# %% [markdown]
# #### [参数设置][1]
#
# [1]: https://blog.csdn.net/wuxiaosi808/article/details/78036633

# %%
# 参数设置
config_xgb = {
    'rounds': 10000
}

params_xgb = {
    'booster': 'gbtree',
    'objective': 'binary:logistic',
    'stratified': True,
    'scale_pos_weights': 51,
    'max_depth': 6,
    'min_child_weight': 2,
    'gamma': 1,
    'subsample': 0.75,
    'colsample_bytree': 0.75,
    'lambda': 1,
    'eta': 0.01,
    'seed': 20,
    'verbose': -1,
    'silent': 1,
    'eval_metric': 'auc'
}

# %% [markdown]
# #### XGBoost 模型训练和预测

# %%
# 定义xgboost模型训练函数，对迭代次数调参
def xgb_train(train_feature, train_label, test_feature, test_label, params, rounds):
    start = time.perf_counter()
    print(train_feature.columns)
    params['scale_pos_weights'] = float(len(train_label[train_label == 0])) / len(train_label[train_label == 1])
    dtrain = xgb.DMatrix(train_feature, label=train_label)
    dtest = xgb.DMatrix(test_feature, label=test_label)
    watchlist = [(dtrain, 'train'), (dtest, 'test')]
    print('XGBoost run : ' + 'round: ' + str(rounds))
    res = xgb.train(params, dtrain, rounds, watchlist, verbose_eval=20, early_stopping_rounds=50)
    elapsed = (time.perf_counter() - start)
    # print('Time used:' + str(elapsed) + 's')
    return res.best_ntree_limit, res.best_score

# 定义gboost模型预测函数
def xgb_predict(train_feature, train_label, test_feature, rounds, params):
    params['scale_pos_weights'] = float(len(train_label[train_label == 0])) / len(train_label[train_label == 1])
    dtrain = xgb.DMatrix(train_feature, label=train_label)
    dtest = xgb.DMatrix(test_feature, label=np.zeros(test_feature.shape[0]))
    watchlist = [(dtrain, 'train')]
    model = xgb.train(params, dtrain, rounds, watchlist, verbose_eval=30)
    predict = model.predict(dtest)
    return model, predict

# %%
iterations_xgb, best_score_xgb = xgb_train(local_train_x, local_train_y, local_test_x, local_test_y, params_xgb, config_xgb['rounds'])
print("迭代次数：{}\n最佳分数：{}".format(iterations_xgb, best_score_xgb))

# %%
model_xgb, pred_xgb = xgb_predict(online_train_x, online_train_y, online_test_x, iterations_xgb, params_xgb)

# %% [markdown]
# #### 模型结果保存

# %%
importance_xgb = pd.DataFrame(model_xgb.get_fscore().items(), 
                              columns=['feature', 'importance']).sort_values('importance', ascending=False)
importance_xgb.to_csv(root_path + 'output/feat_imp/importance-xgb-20220504-%f(r%d).csv' %
                      (best_score_xgb, iterations_xgb), index=False)

# %%
# 定义提交结果函数
def store_result(test_index, pred, name):
    result = pd.DataFrame({'click_id': test_index, 'is_attributed': pred})
    result.to_csv(root_path + 'output/sub/' + name + '.csv', index=False, sep=',')
    return result

# 提交预测结果
test_click_id = pd.read_csv(root_path + 'input/test.csv', header=0, sep=',', dtype=dtypes, usecols=['click_id'])
res_xgb = store_result(test_click_id.click_id, pred_xgb, '20220504-xgb-%f(r%d)' % (best_score_xgb, iterations_xgb))

# %% [markdown]
# ### 模型二 [LightGBM][1]
#
# [1]: https://www.cnblogs.com/simpleye1/p/13946653.html

# %% [markdown]
# #### 参数设置

# %%
# 参数设置
config_lgb = {
    'rounds': 10000
}

params_lgb = {
    'boosting_type': 'gbdt',
    'objective': 'xentropy',
    'metric': 'auc',
    'learning_rate': 0.02,
    'scale_pos_weight': 200,  
    'num_leaves': 31, 
    'max_depth': -1,  
    'min_child_samples': 100,
    'max_bin': 128,  
    'subsample': 0.7,  
    'subsample_freq': 1,  
    'colsample_bytree': 0.9,
    'min_child_weight': 0,
    'subsample_for_bin': 200000,  
    'min_split_gain': 0,  
    'reg_alpha': 0.99,  
    'reg_lambda': 0.9,  
    'nthread': 24,
    'verbose': -1,
    'seed': 8
}

# %% [markdown]
# #### LightGBM 模型训练和预测

# %%
# 定义lightgbm模型训练函数，对迭代次数进行调参
def lgb_train(train_feature, train_label, test_feature, test_label, params, rounds):
    start = time.perf_counter()
    print(train_feature.columns)
    params['scale_pos_weight'] = float(len(train_label[train_label == 0])) / len(train_label[train_label == 1])
    dtrain = lgb.Dataset(train_feature, label=train_label, categorical_feature=['app', 'device', 'os', 'channel', 'hour'])
    dtest = lgb.Dataset(test_feature, label=test_label, categorical_feature=['app', 'device', 'os', 'channel', 'hour'])
    print('LightGBM run : ' + 'round: ' + str(rounds))
    res = lgb.train(params, dtrain, rounds, valid_sets=[dtest], valid_names=['test'], verbose_eval=10, early_stopping_rounds=20)
    elapsed = (time.perf_counter() - start)
    # print('Time used:', elapsed, 's')
    return res.best_iteration, res.best_score['test']['auc']

# 定义lightgbm模型预测函数
def lgb_predict(train_feature, train_label, test_feature, rounds, params):
    dtrain = lgb.Dataset(train_feature, label=train_label, categorical_feature=['app', 'device', 'os', 'channel', 'hour'])
    model = lgb.train(params, dtrain, rounds, valid_sets=[dtrain], verbose_eval=10)
    predict = model.predict(test_feature)
    return model, predict

# %%
iterations_lgb, best_score_lgb = lgb_train(local_train_x, local_train_y, local_test_x, local_test_y, params_lgb, config_lgb['rounds'])
print("迭代次数：{}\n最佳分数：{}".format(iterations_lgb, best_score_lgb))

# %%
model_lgb, pred_lgb = lgb_predict(online_train_x, online_train_y, online_test_x, iterations_lgb, params_lgb)

# %% [markdown]
# #### 模型结果保存

# %%
importance_lgb = sorted(zip(online_train_x.columns, model_cv_lgb.feature_importance("gain")), key=lambda x: x[1], reverse=True)
importance_lgb = pd.DataFrame({'feature': importance_lgb})
importance_lgb = importance_lgb.apply(lambda x: pd.Series(x['feature']), axis=1)
importance_lgb.columns = ['feature', 'importance']
importance_lgb.to_csv(root_path + 'output/feat_imp/importance-lgb-20180507-%f(r%d).csv' %
                      (best_score_lgb, iterations_lgb), index=False)

# %%
res_lgb = store_result(test_click_id.click_id, pred_lgb, '20220504-lgb-%f(r%d)' % (best_score_lgb, iterations_lgb))
del test_click_id
gc.collect()

# %%
# 保存模型
log('Save model...')
model_lgb.save_model(root_path + 'output/model/lgb-%f(r%d).txt' % (best_score_lgb, iterations_lgb))
log('Model best score:' + str(best_score_lgb))
log('Model best iteration:' + str(iterations_lgb))
log('Save model done!')
# 重新加载模型
# model_lgb = lgb.Booster(model_file=root_path + 'output/model/lgb-0.981609(r2100).txt')
